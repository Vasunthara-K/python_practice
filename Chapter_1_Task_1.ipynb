# %% [markdown]
# ## Task 1
# Give 2 examples of all String functions which should be meaningful.

# %% [markdown]
# ## Example 1

# %%
text = " Machine Learning  "
print(len(text))
print(text[3])
print(text[1:5])
print(text.islower())
print(text.isupper())
print(text.upper())
print(text.lower())
print(text.lstrip())
print(text.rstrip())
print(text.strip())
print(text.count("n"))
print(text.replace("Machine","Python"))
print(text.find("L")) 
sentence = "reset password using username","use userid for verification"
print(" ".join(sentence))
item = "Apple-Banana-Grapes"
print(fruits.split("-"))
# Out:
# 19
# c
# Mach
# False
# False
#  MACHINE LEARNING
#  machine learning
# Machine Learning
#  Machine Learning
# Machine Learning
# 3
#  Python Learning
# 9
# reset password using username use userid for verification
# ['Apple', 'Banana', 'Grapes']

# %% [markdown]
# ## Example 2

# %%
text_1 = "data science"
text_1.upper()
text_1.title()
# Out:
# 'Data Science'

# %%
text_2 = "PYTHON"
text_2.lower()
# Out:
# 'python'

# %%
text_1 = "Data science machine learning"
text_1.title()
# Out:
# 'Data Science Machine Learning'

# %%
text_1 = "data science Machine Learning"
text_1.capitalize()
# Out:
# 'Data science machine learning'

# %%
text = " Chennai "
text.strip()
# Out:
# 'Chennai'

# %%
text = " Python"
text.lstrip()
# Out:
# 'Python'

# %%
text = "Machine Learning  "
text.rstrip()
# Out:
# 'Machine Learning'

# %%
text = "reset password using email"
text.replace("email","userid")
# Out:
# 'reset password using userid'

# %%
text = "reset password using email"
text.replace(" ","_")
# Out:
# 'reset_password_using_email'

# %%
text = "vasu@gmail.com"
text.find("@")
# Out:
# 4

# %%
text = "vasu@gmail.com"
text.find("at")
# Out:
# -1

# %%
text = "vasu@gmail.com"
text.index("@")
# Out:
# 4

# %%
text = "vasu@gmail.com"
text.index("at")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 2
#       1 text = "vasu@gmail.com"
# ----> 2 text.index("at")
#
# ValueError: substring not found

# %%
text = "reset password using email or userid"
text.count("or")
# Out:
# 2

# %%
python_libraries = "Pandas Numpy Scikitlearn Matplotlib random"
python_libraries.split(" ")
# Out:
# ['Pandas', 'Numpy', 'Scikitlearn', 'Matplotlib', 'random']

# %%
python_libraries = "Pandas Numpy Scikitlearn Matplotlib random"
"|".join(python_libraries)
# Out:
# 'P|a|n|d|a|s| |N|u|m|p|y| |S|c|i|k|i|t|l|e|a|r|n| |M|a|t|p|l|o|t|l|i|b| |r|a|n|d|o|m'

# %%
python_libraries = 'Pandas', 'Numpy', 'Scikitlearn', 'Matplotlib', 'random'
"|".join(python_libraries)
# Out:
# 'Pandas|Numpy|Scikitlearn|Matplotlib|random'

# %%
python_libraries = "Pandas Numpy Scikitlearn Matplotlib random"
python_libraries.isalpha()
# Out:
# False

# %%
python_libraries = "Pandas Numpy Scikitlearn Matplotlib random"
python_libraries.isdigit()
type(python_libraries)
# Out:
# str

# %%
python_libraries = "Pandas Numpy Scikitlearn Matplotlib random"
python_libraries.isspace()
# Out:
# False

# %%
python_libraries = "123"
python_libraries.isalnum()
# Out:
# True

# %%
python_libraries = "emp_101"
python_libraries.isalnum()
# Out:
# False

# %%
python_libraries = " "
python_libraries.isspace()
# Out:
# True
