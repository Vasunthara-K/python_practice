# %% [markdown]
# ## Task 3
# Rock, Paper, Scissors Game

# %%
import random

def rps_game():
    system_choice = random.randint(1,4)
    for i in range(1):
        try:
            print("1-Rock 2-paper 3-scissor")
            user_input = abs(int(input("\nEnter your choice")))

            if user_input > 3:
                print("Number greater than 3 is not allowed")
            elif system_choice == user_input:
                print("Match....You Win",user_input,system_choice)
            else :
                 print("\ndidn't match",user_input,system_choice)        
        except:
            print("\nEnter only numbers between 1-3")
rps_game()
while True:
    continue_game=input("\nYou want to continue:Yes/No")

    if continue_game.lower() == "yes":
        game()
        continue
    elif continue_game.lower() == "no":
        print("\nThanks for participating")
        break
# Out:
# 1-Rock 2-paper 3-scissor
# Enter your choice -4
# Number greater than 3 is not allowed
# You want to continue:Yes/No yes
# 1-Rock 2-paper 3-scissor
# Enter your choice q
# Enter only numbers between 1-3
# You want to continue:Yes/No yes
# 1-Rock 2-paper 3-scissor
# Enter your choice -4
# Number greater than 3 is not allowed
# You want to continue:Yes/No yes
# 1-Rock 2-paper 3-scissor
# Enter your choice 3
# didn't match 3 2
# You want to continue:Yes/No no
# Thanks for participating

# %% [markdown]
# ## Task 4: Word Guessing Game

# %%
import random
option = ["python", "machine", "learn", "bridge"]

def word_guessing_game():
    
    system_choice = random.choice(option)
    print("Guess your word -------")
    attempt = 0
    for i in system_choice:
        
         user_letter = input("\nEnter your guess letter")
         user_letter = user_letter.lower()
         attempt = attempt +1
        
         if attempt >=6:
             print("Your attempts are over")
             break
         elif user_letter == i:
             print("your guess matched",user_letter,i)
             
         else:
             print("Your guess didn't match")
             print(i)

word_guessing_game()
# Out:
# Guess your word -------
# Enter your guess letter p
# your guess matched p p
# Enter your guess letter y
# your guess matched y y
# Enter your guess letter t
# your guess matched t t
# Enter your guess letter h
# your guess matched h h
# Enter your guess letter o
# your guess matched o o
# Enter your guess letter n
# Your attempts are over

# %%
system_choice = "learn"
attempt = 1

for i in system_choice:
    try:
        user_letter = input("Enter your letter")
        user_letter = user_letter.lower()
        if attempt >=6:
            print("Your attempts are over")
            break
        elif user_letter == i:
            print("your guess matched",user_letter,i)
            attempt = attempt +1
        else:
            print("Your guess didn't match")
            print(i)
            attempt = attempt +1
            
    except:
        print("Enter only letters")
# Out:
# Enter your letter l
# your guess matched l l
# Enter your letter e
# your guess matched e e
# Enter your letter a
# your guess matched a a
# Enter your letter r
# your guess matched r r
# Enter your letter n
# your guess matched n n

# %%
        user_letter = input("Enter your 1st letter")
        user_letter = user_letter.lower()
print(user_letter)
# Out:
# Enter your 1st letter A
# a
